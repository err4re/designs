# %%
import sys
sys.path.insert(0, '../') # add the parent directory of components to sys.path


import importlib

from components import frame
importlib.reload(frame)
from components.frame import Frame, FrameParams

from phidl import quickplot as qp

# %%
frame = Frame()
frame.generate_frame(frame_params=FrameParams())

qp(frame.device)

frame.device.write_gds(filename='Component_Frame.gds')
# Out:
# 'Component_Frame.gds'
