# %%
import sys
sys.path.insert(0, '../') # add the parent directory of components to sys.path


import importlib

from components import double_square_spiral 
importlib.reload(double_square_spiral)
from components.double_square_spiral import DoubleSquareSpiral, SquareSpiralParams

from phidl import quickplot as qp

# %%
spiral = DoubleSquareSpiral()
spiral.generate_double_square_spiral(spiral_params=SquareSpiralParams())

qp(spiral.device)

spiral.device.write_gds(filename='Component_Double_Square_Spiral.gds')
# Out:
# 'Component_Double_Square_Spiral.gds'
