# %%
import sys
sys.path.insert(0, '../') # add the parent directory of components to sys.path

import importlib

from components import junction 
importlib.reload(junction)
from components.junction import JJ, JJParams

from phidl import quickplot as qp

# %%
josephson_junction = JJ()
josephson_junction.generate_jj(jj_params=JJParams())

qp(josephson_junction.device)

josephson_junction.device.write_gds(filename='Component_JJ_default.gds')
# Out:
# 'Component_JJ_default.gds'

# %%
josephson_junction = JJ()
josephson_junction.generate_jj(jj_params=JJParams(undercut_shape='H_rounded'))

qp(josephson_junction.device)

josephson_junction.device.write_gds(filename='Component_JJ_H_rounded.gds')
# Out:
# 'Component_JJ_H_rounded.gds'

# %%
josephson_junction = JJ()
josephson_junction.generate_jj(jj_params=JJParams(undercut_shape='H_boxes'))

qp(josephson_junction.device)

josephson_junction.device.write_gds(filename='Component_JJ_H_boxes.gds')
# Out:
# 'Component_JJ_H_boxes.gds'
