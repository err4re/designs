# %%
import sys
sys.path.insert(0, '../') # add the parent directory of components to sys.path


from components.layerset.defaults import DEFAULT_DESIGN_LAYER_SET

ls = DEFAULT_DESIGN_LAYER_SET.layer_set

ls['ebeam']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\aw270929\Miniconda3\envs\phidl\lib\site-packages\phidl\device_layout.py:418, in LayerSet.__getitem__(self, val)
#     417 try:
# --> 418     return self._layers[val]
#     419 except Exception:
#
# KeyError: 'ebeam'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 9
#       5 from components.layerset.defaults import DEFAULT_DESIGN_LAYER_SET
#       7 ls = DEFAULT_DESIGN_LAYER_SET.layer_set
# ----> 9 ls['ebeam']
#
# File c:\Users\aw270929\Miniconda3\envs\phidl\lib\site-packages\phidl\device_layout.py:420, in LayerSet.__getitem__(self, val)
#     418     return self._layers[val]
#     419 except Exception:
# --> 420     raise ValueError(
#     421         "[PHIDL] LayerSet: Tried to access layer "
#     422         'named "%s"' % (val) + " which does not exist"
#     423     )
#
# ValueError: [PHIDL] LayerSet: Tried to access layer named "ebeam" which does not exist

# %%
import sys
sys.path.insert(0, '../') # add the parent directory of components to sys.path

import importlib

from components.devices import josephson_junction
importlib.reload(josephson_junction)
from components.devices.josephson_junction import DolanJunction, DolanJunctionParams

from phidl import quickplot as qp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\aw270929\Miniconda3\envs\phidl\lib\site-packages\phidl\device_layout.py:418, in LayerSet.__getitem__(self, val)
#     417 try:
# --> 418     return self._layers[val]
#     419 except Exception:
#
# KeyError: 'ebeam'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       2 sys.path.insert(0, '../') # add the parent directory of components to sys.path
#       4 import importlib
# ----> 6 from components.devices import josephson_junction
#       7 importlib.reload(josephson_junction)
#       8 from components.devices.josephson_junction import DolanJunction, DolanJunctionParams
#
# File l:\alex\phidl\QRCSJ_refactor\tests\..\components\devices\josephson_junction.py:27
#      22 default_ls = DEFAULT_DESIGN_LAYER_SET.layer_set
#      25 ### define Dolan junction parameters
#      26 @dataclass(frozen=True)
# ---> 27 class DolanJunctionParams:
#      28
#      29     # overlap between structures for increased robustness of ebeam design
#      30     overlap: float = 0.1
#      32     junction_total_length: float = 10
#
# File l:\alex\phidl\QRCSJ_refactor\tests\..\components\devices\josephson_junction.py:106, in DolanJunctionParams()
#     102 stress_boxes_undercut_width: float = 0.4
#     104 undercut_shape: str = 'H_asym_slits'
# --> 106 layer: Layer = default_ls['ebeam']
#     107 junction_layer: Layer = default_ls['ebeam_junctions']
#     108 junction_line_layer: Layer = default_ls['ebeam_junctions']
#
# File c:\Users\aw270929\Miniconda3\envs\phidl\lib\site-packages\phidl\device_layout.py:420, in LayerSet.__getitem__(self, val)
#     418     return self._layers[val]
#     419 except Exception:
# --> 420     raise ValueError(
#     421         "[PHIDL] LayerSet: Tried to access layer "
#     422         'named "%s"' % (val) + " which does not exist"
#     423     )
#
# ValueError: [PHIDL] LayerSet: Tried to access layer named "ebeam" which does not exist

# %%
dolan_params = DolanJunctionParams()

qp(DolanJunction.build_arm_rect(dolan_params))
