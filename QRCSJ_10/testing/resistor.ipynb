# %%
import sys
sys.path.insert(0, '../') # add the parent directory of components to sys.path


import importlib

from components import resistor
importlib.reload(resistor)
from components.resistor import Resistor, ResParams

from phidl import quickplot as qp

# %%
resistor = Resistor()
resistor.generate_resistor(res_params=ResParams())

qp(resistor.device)

resistor.device.write_gds(filename='Component_Resistor.gds')
# Out:
# 'Component_Resistor.gds'

# %%
resistor = Resistor()
resistor.generate_resistor(res_params=ResParams(mirrored_x_axis=True))

qp(resistor.device)

resistor.device.write_gds(filename='Component_Resistor_Mirrored_x.gds')
# Out:
# 'Component_Resistor_Mirrored_x.gds'

# %%
resistor = Resistor()
resistor.generate_resistor(res_params=ResParams(num_segments=3, total_spacing=9, segment_length=10))

qp(resistor.device)

resistor.device.write_gds(filename='Component_Resistor_odd.gds')
# Out:
# 'Component_Resistor_odd.gds'

# %%
resistor = Resistor()
resistor.generate_resistor(res_params=ResParams(num_segments=3, total_spacing=9, segment_length=10, mirrored_x_axis=True))

qp(resistor.device)

resistor.device.write_gds(filename='Component_Resistor_odd_mirrored_x.gds')
# Out:
# 'Component_Resistor_odd_mirrored_x.gds'

# %%
resistor = Resistor()
resistor.generate_resistor(res_params=ResParams(num_segments=4, total_spacing=12, segment_length=10))

qp(resistor.device)

resistor.device.write_gds(filename='Component_Resistor_4.gds')
# Out:
# 'Component_Resistor_4.gds'

# %%
resistor = Resistor()
resistor.generate_resistor(res_params=ResParams(num_segments=4, spacing=4, segment_length=10, adaptive_spacing=False))

qp(resistor.device)

resistor.device.write_gds(filename='Component_Resistor_4_no_adaptive_spacing.gds')
# Out:
# 'Component_Resistor_4_no_adaptive_spacing.gds'

# %%
resistor = Resistor()
resistor.generate_resistor(res_params=ResParams(small_resistor=True, num_segments=7, total_spacing=12, segment_length=10, connectors=True))

qp(resistor.device)

resistor.device.write_gds(filename='Component_Small_Resistor.gds')
# Out:
# 'Component_Small_Resistor.gds'

# %%
resistor = Resistor()
resistor.generate_resistor(res_params=ResParams(small_resistor=True, num_segments=7, total_spacing=12, segment_length=10, connectors=False, mirrored_x_axis=True))

qp(resistor.device)

resistor.device.write_gds(filename='Component_Small_Resistor_Mirrored_x.gds')
# Out:
# 'Component_Small_Resistor_Mirrored_x.gds'

# %%
Arm, Undercut = Resistor.create_right_arm_small(ResParams(num_segments=4, spacing=2, adaptive_spacing=False, segment_length=25))

qp([Arm, Undercut])

# %%
Arm, Undercut = Resistor.create_right_arm_small(ResParams(num_segments=4, spacing=2, adaptive_spacing=False, segment_length=25, opposite_side_connectors=True))

qp([Arm, Undercut])

# %%
Arm, Undercut = Resistor.create_arm(ResParams(num_segments=4, spacing=2, adaptive_spacing=False, segment_length=25, opposite_side_connectors=True, small_resistor=True))

qp([Arm, Undercut])

# %%
res_params = ResParams(num_segments=4, spacing=2, adaptive_spacing=False, segment_length=25, opposite_side_connectors=True, small_resistor=True)

resistor = Resistor()
resistor.generate_resistor(res_params)

qp(resistor.device)

# %%
Arm, Undercut = Resistor.create_right_arm_small_mirrored(ResParams(num_segments=4, spacing=2, adaptive_spacing=False, segment_length=25))

qp([Arm, Undercut])

# %%
Arm, Undercut = Resistor.create_right_arm_small_mirrored(ResParams(num_segments=4, spacing=2, adaptive_spacing=False, segment_length=25, opposite_side_connectors=True))

qp([Arm, Undercut])

# %%
Segments = Resistor.create_res_segments(ResParams(num_segments=4, spacing=2, adaptive_spacing=False, segment_length=25, opposite_side_connectors=True))

qp(Segments)

# %%
resistor = Resistor()
resistor.generate_resistor(res_params=ResParams(num_segments=3, spacing=4, segment_length=10, symmetric=True))

qp(resistor.device)

resistor.device.write_gds(filename='Component_Resistor_symm.gds')
# Out:
# 'Component_Resistor_symm.gds'

# %%
resistor = Resistor()
resistor.generate_resistor(res_params=ResParams(num_segments=3, total_spacing=10, adaptive_spacing=True, segment_length=10, symmetric=True, mirrored_x_axis=True))

qp(resistor.device)

resistor.device.write_gds(filename='Component_Resistor_symm_mirrored.gds')
# Out:
# 'Component_Resistor_symm_mirrored.gds'
