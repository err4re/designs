# %%
import sys
sys.path.insert(0, '../') # add the parent directory of components to sys.path


import importlib

from components import double_square_spiral 
importlib.reload(double_square_spiral)
from components.double_square_spiral import DoubleSquareSpiral, SquareSpiralParams

from components import double_square_spiral_two_wire
importlib.reload(double_square_spiral_two_wire)
from components.double_square_spiral_two_wire import DoubleSquareSpiral2Wire, PadParams

from phidl import quickplot as qp

# %%
spiral = DoubleSquareSpiral2Wire()
spiral.generate_double_square_spiral_two_wire(spiral_params=SquareSpiralParams(connector_length=8, num_turns=8, turn_spacing_x=2, turn_spacing_y=2), pad_params=PadParams)

qp(spiral.device)

spiral.device.write_gds(filename='Component_Double_Square_Spiral_Two_Wire.gds')
# Out:
# 'Component_Double_Square_Spiral_Two_Wire.gds'
