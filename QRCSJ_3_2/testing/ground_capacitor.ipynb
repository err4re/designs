# %%
import sys
sys.path.insert(0, '../') # add the parent directory of components to sys.path


import importlib

from components import ground_capacitor
importlib.reload(ground_capacitor)
from components.ground_capacitor import GroundCapa, GroundCapaParams

from phidl import quickplot as qp

# %%
ground_capa = GroundCapa()
ground_capa.generate_ground_capa(capa_params=GroundCapaParams())

qp(ground_capa.device)

ground_capa.device.write_gds(filename='Component_Ground_Capacitor.gds')
# Out:
# 'Component_Ground_Capacitor.gds'
