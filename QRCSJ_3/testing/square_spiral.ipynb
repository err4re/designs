# %%
import importlib

import square_spiral as square_spiral
importlib.reload(square_spiral)
from square_spiral import SquareSpiral, SquareSpiralParams

from phidl import quickplot as qp

# %%
spiral = SquareSpiral()
spiral.generate_square_spiral(spiral_params=SquareSpiralParams())

qp(spiral.device)

spiral.device.write_gds(filename='Component_Square_Spiral.gds')
# Out:
# 'Component_Square_Spiral.gds'

# %%
spiral = SquareSpiral()
spiral.generate_square_spiral(spiral_params=SquareSpiralParams(num_turns=5, left_side_undercut=False))

qp(spiral.device)

spiral.device.write_gds(filename='Component_Square_Spiral_5.gds')
# Out:
# 'Component_Square_Spiral_5.gds'
